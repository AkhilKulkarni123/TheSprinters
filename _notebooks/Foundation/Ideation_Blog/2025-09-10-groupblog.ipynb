# %% [markdown]
# ---
# layout: post
# title: Group Ideation
# description: "Become a Learning Experience Designer by improving Open Coding Society's new student onboarding experience."
# courses: {'csse': {'week': 0}, 'csp': {'week': 0}, 'csa': {'week': 0}}
# comments: true
# toc: true
# permalink: /groupblog
# ---

# %% [markdown]
# Shayan and Darshan - Snake Game and Rock Paper Scissors
# Akhil, Samarth, Rudra - API's and Tic Tac Toe Game

# %% [markdown]
# 1. Shayan has Snake and Tic Tac Toe game code from last year and previous projects, so he will create lessons in notebooks and demos of his game, which are curently in his student. repository.

# %% [markdown]
# 2. Akhil, Samarth and Rudra will also be creating notebooks on API Lessons, and will be adding Tic Tac Toe lessons and demos, which are currently in the student repositories.
