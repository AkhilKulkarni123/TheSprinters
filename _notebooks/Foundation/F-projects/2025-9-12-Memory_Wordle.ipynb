# %% [markdown]
# ---
# title: Memory Game lesson
# description: Learn to code Wordle in Javascript and implement core concepts in software with comments
# comments: false
# layout: post
# permalink: /Memory_Wordle/lesson
# ---

# %%
# %%javascript
# // Wordle game: Guess the 5-letter secret word within 6 tries
#
# // The secret word to guess (normally, you'd pick this randomly)
# const secretWord = "APPLE";
#
# // Maximum attempts allowed
# const maxAttempts = 6;
#
# // Function to check the user's guess
# function checkGuess(guess) {
#   // Make guess uppercase to match secretWord
#   guess = guess.toUpperCase();
#
#   // Array to store feedback for each letter
#   // 'G' = correct letter and position (green)
#   // 'Y' = correct letter wrong position (yellow)
#   // 'B' = letter not in word (black/gray)
#   let feedback = [];
#
#   // First, mark correct letters in correct positions
#   for (let i = 0; i < 5; i++) {
#     if (guess[i] === secretWord[i]) {
#       feedback[i] = "G"; // Green
#     } else if (secretWord.includes(guess[i])) {
#       feedback[i] = "Y"; // Yellow
#     } else {
#       feedback[i] = "B"; // Black/gray
#     }
#   }
#   return feedback;
# }
#
# // Main game loop
# function playWordle() {
#   let attempts = 0;
#
#   while (attempts < maxAttempts) {
#     // Ask the user for a guess (in a browser, you could use prompt)
#     let guess = prompt(`Attempt ${attempts + 1}: Enter a 5-letter word`).toUpperCase();
#
#     if (guess.length !== 5) {
#       alert("Please enter exactly 5 letters.");
#       continue; // Skip this loop iteration
#     }
#
#     attempts++;
#
#     // Get feedback on the guess
#     let result = checkGuess(guess);
#
#     // Display feedback to user (for simplicity, just show G/Y/B)
#     alert(`Feedback: ${result.join("")}`);
#
#     // Check if user guessed correctly
#     if (guess === secretWord) {
#       alert(`Congrats! You guessed the word in ${attempts} tries.`);
#       return;
#     }
#   }
#
#   alert(`Sorry! The secret word was ${secretWord}. Better luck next time!`);
# }
#
# // Start the game
# playWordle();
# Out:
#   Cell In[2], line 1
#     // Wordle game: Guess the 5-letter secret word within 6 tries
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # How It Works (Quick Summary)
#
# You have a secret 5-letter word.
#
# You get up to 6 tries to guess it.
#
# For each guess, the program tells you which letters are correct and in the right place (G), which are correct but in the wrong place (Y), and which aren't in the word (B).
#
# You win if you guess the word within 6 tries.

# %% [markdown]
# # Hacks for Students
#
# Random Word:
# Replace the fixed secret word with a random choice from a small list of words.
#
# Color Feedback:
# Instead of showing letters "G", "Y", "B", change the output to show colored letters or emojis (🟩, 🟨, ⬛).
#
# Input Validation:
# Prevent guesses that are not real words by checking against a list of allowed words.
#
# UI Upgrade:
# Instead of alerts and prompts, create a simple HTML page with input boxes and display feedback directly on the page.
#
# Guess History:
# Show all previous guesses and their feedback so the player can keep track.
