# %% [markdown]
# ---
# title: Algorithm Efficiency JS Lesson
# description: Learning about Algorithmic Effiency in Javascript
# comments: false
# layout: post
# toc: true
# permalink: /csp/big-idea-3/Algorithm_Efficiency/p3/LessonJS
# ---
