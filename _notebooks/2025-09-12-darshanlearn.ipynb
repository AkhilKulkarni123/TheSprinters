# %% [markdown]
# ---
# layout: post
# title: My experience
# description: "darshans thing"
# type: objectives
# courses: {'csse': {'week': 0}, 'csp': {'week': 0}, 'csa': {'week': 0}}
# comments: false
# toc: true
# permalink: /darshan
# ---

# %% [markdown]
# 1. Picture of me
# 2. Button that goes to india

# %%
<img src="images/me.png" alt="My Image" width="300">
