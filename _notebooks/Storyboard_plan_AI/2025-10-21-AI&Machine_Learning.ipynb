# %% [markdown]
# ---
# layout: post
# title: "Quest of Code AI Storyboard"
# description: Our roadmap and storyboard for Quest of Code AI.
# permalink: /QCAIstoryboard
# author: Rudra J, Akhil K.
# ---

# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f172a 0%, #1e293b 100%); padding: 40px; border-radius: 15px; color: #e2e8f0;">
#
# <h1 style="margin: 0 0 20px 0; color: #f1f5f9;">🚗 <span style="font-weight: bold; font-size: 36px;">AI Road Trip: A Journey Through Machine Learning</span></h1>
#
# <div style="background: rgba(255, 255, 255, 0.1); padding: 20px; border-radius: 10px; margin: 20px 0; backdrop-filter: blur(10px); border: 2px solid rgba(255, 255, 255, 0.2);">
#   <h2 style="color: #f1f5f9; text-align: center; margin: 0;">🗺️ Our Route</h2>
#   <p style="color: #f1f5f9; text-align: center; font-size: 24px; margin: 10px 0; font-weight: bold;">
#     San Diego → Los Angeles → San Francisco → Seattle
#   </p>
# </div>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(255, 107, 107, 0.15); padding: 15px; border-radius: 8px; border-left: 5px solid #ff6b6b; color: #f1f5f9; margin: 20px 0; display: flex; align-items: center; justify-content: space-between;">
#   <h2 style="margin: 0; color: #fca5a5;">🌴 Stop 1: San Diego - "Planning the Journey"</h2>
#   <img src="{{site.baseurl}}/images/balboa.png" alt="Balboa Park" style="max-width: 200px; border-radius: 8px; margin-left: 20px;">
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#   <tr style="background-color: rgba(255, 107, 107, 0.1);">
#     <td style="padding: 15px; border: 2px solid #ff6b6b; border-radius: 5px;">
#       <strong style="color: #ff6b6b; font-size: 18px;">🤖 AI Concept:</strong> <span style="color: #e2e8f0;">Prompt Engineering & Input Design</span>
#     </td>
#   </tr>
# </table>
#
# <h3 style="color: #f1f5f9; margin: 20px 0 10px 0;">📝 Activity: Generating an Itinerary</h3>
#
# <div style="background-color: rgba(255, 255, 255, 0.05); padding: 20px; border-left: 4px solid #ff6b6b; margin: 15px 0; border-radius: 5px; color: #e2e8f0;">
#   <p style="margin: 0;">Just like planning a road trip, we start by telling our AI assistant where we want to go and what we want to see. This is <strong style="color: #fca5a5;">prompt engineering</strong> - the art of asking the right questions to get the best results.</p>
# </div>
#
# <p style="color: #f1f5f9; margin: 15px 0;"><strong>Example Prompt:</strong></p>
# <div style="background: rgba(0, 0, 0, 0.4); padding: 15px; border-radius: 5px; color: #cbd5e1; font-family: monospace; margin: 15px 0; border: 1px solid rgba(255, 255, 255, 0.1);">
# "Plan a 4-day road trip from San Diego to Seattle, <br>
# including must-see stops, dining recommendations, <br>
# and scenic routes."
# </div>
#
# <div style="background: rgba(255, 107, 107, 0.15); padding: 15px; border-radius: 8px; margin: 15px 0; border: 2px solid #ff6b6b;">
#   <strong style="color: #fca5a5;">💡 Key Learning:</strong> <span style="color: #e2e8f0;">The quality of your AI output depends on the clarity of your input - just like a good road trip starts with a solid plan!</span>
# </div>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(78, 205, 196, 0.15); padding: 15px; border-radius: 8px; border-left: 5px solid #4ecdc4; color: #f1f5f9; margin: 20px 0; display: flex; align-items: center; justify-content: space-between;">
#   <h2 style="margin: 0; color: #5eead4;">🎬 Stop 2: Los Angeles - "Adapting on the Fly"</h2>
#   <img src="{{site.baseurl}}/images/sofi.png" alt="SoFi Stadium" style="max-width: 200px; border-radius: 8px; margin-left: 20px;">
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#   <tr style="background-color: rgba(78, 205, 196, 0.1);">
#     <td style="padding: 15px; border: 2px solid #4ecdc4; border-radius: 5px;">
#       <strong style="color: #4ecdc4; font-size: 18px;">🤖 AI Concept:</strong> <span style="color: #e2e8f0;">Real-Time Learning & Context Awareness</span>
#     </td>
#   </tr>
# </table>
#
# <h3 style="color: #f1f5f9; margin: 20px 0 10px 0;">🔄 The Detour Experience</h3>
#
# <div style="background-color: rgba(255, 255, 255, 0.05); padding: 20px; border-left: 4px solid #4ecdc4; margin: 15px 0; border-radius: 5px; color: #e2e8f0;">
#   <p style="margin: 0;">On the road, plans change - traffic jams, weather, new recommendations from locals. Similarly, AI models maintain <strong style="color: #5eead4;">context</strong> throughout a conversation, learning from each exchange and adapting their responses.</p>
# </div>
#
# <div style="background: rgba(78, 205, 196, 0.15); padding: 15px; border-radius: 8px; margin: 15px 0; border: 2px solid #4ecdc4;">
#   <strong style="color: #5eead4;">💡 Key Learning:</strong> <span style="color: #e2e8f0;">Like adjusting your route based on real-time traffic, AI can refine its understanding as you provide more information and feedback.</span>
# </div>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(255, 217, 61, 0.15); padding: 15px; border-radius: 8px; border-left: 5px solid #ffd93d; color: #f1f5f9; margin: 20px 0; display: flex; align-items: center; justify-content: space-between;">
#   <h2 style="margin: 0; color: #fde047;">🌉 Stop 3: San Francisco - "Pattern Recognition"</h2>
#   <img src="{{site.baseurl}}/images/sanfran.png" alt="Golden Gate Bridge" style="max-width: 200px; border-radius: 8px; margin-left: 20px;">
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#   <tr style="background-color: rgba(255, 217, 61, 0.1);">
#     <td style="padding: 15px; border: 2px solid #ffd93d; border-radius: 5px;">
#       <strong style="color: #ffd93d; font-size: 18px;">🤖 AI Concept:</strong> <span style="color: #e2e8f0;">Machine Learning & Neural Networks</span>
#     </td>
#   </tr>
# </table>
#
# <h3 style="color: #f1f5f9; margin: 20px 0 10px 0;">🧠 Recognizing the Best Routes</h3>
#
# <div style="background-color: rgba(255, 255, 255, 0.05); padding: 20px; border-left: 4px solid #ffd93d; margin: 15px 0; border-radius: 5px; color: #e2e8f0;">
#   <p style="margin: 0;">By now, we've driven hundreds of miles and noticed patterns: coastal highways are scenic but slower, highways are faster but less interesting. AI learns the same way - by analyzing thousands of examples to <strong style="color: #fde047;">recognize patterns</strong> and make predictions.</p>
# </div>
#
# <div style="background: rgba(255, 217, 61, 0.15); padding: 15px; border-radius: 8px; margin: 15px 0; border: 2px solid #ffd93d;">
#   <strong style="color: #fde047;">💡 Key Learning:</strong> <span style="color: #e2e8f0;">Just as experienced travelers learn which routes work best, AI models train on vast datasets to identify patterns and make intelligent recommendations.</span>
# </div>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(162, 155, 254, 0.15); padding: 15px; border-radius: 8px; border-left: 5px solid #a29bfe; color: #f1f5f9; margin: 20px 0; display: flex; align-items: center; justify-content: space-between;">
#   <h2 style="margin: 0; color: #c4b5fd;">🌲 Stop 4: Seattle - "The Destination & Reflection"</h2>
#   <img src="{{site.baseurl}}/images/seattle.png" alt="Space Needle" style="max-width: 200px; border-radius: 8px; margin-left: 20px;">
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 15px 0;">
#   <tr style="background-color: rgba(162, 155, 254, 0.1);">
#     <td style="padding: 15px; border: 2px solid #a29bfe; border-radius: 5px;">
#       <strong style="color: #a29bfe; font-size: 18px;">🤖 AI Concept:</strong> <span style="color: #e2e8f0;">Continuous Improvement & Iteration</span>
#     </td>
#   </tr>
# </table>
#
# <h3 style="color: #f1f5f9; margin: 20px 0 10px 0;">🎯 Journey's End & Lessons Learned</h3>
#
# <div style="background-color: rgba(255, 255, 255, 0.05); padding: 20px; border-left: 4px solid #a29bfe; margin: 15px 0; border-radius: 5px; color: #e2e8f0;">
#   <p style="margin: 0;">Every road trip teaches us something new. We might take a different route next time, pack differently, or visit new places. This is <strong style="color: #c4b5fd;">iteration</strong> - the process of learning from experience and improving.</p>
# </div>
#
# <div style="background: rgba(162, 155, 254, 0.15); padding: 15px; border-radius: 8px; margin: 15px 0; border: 2px solid #a29bfe;">
#   <strong style="color: #c4b5fd;">💡 Key Learning:</strong> <span style="color: #e2e8f0;">AI systems improve through feedback loops, user interactions, and retraining - always evolving to serve better, just like we become better travelers with each journey.</span>
# </div>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(255, 255, 255, 0.1); color: #f1f5f9; padding: 20px; border-radius: 10px; text-align: center; margin: 30px 0; border: 2px solid rgba(255, 255, 255, 0.2);">
#   <h2 style="margin: 0; color: #f1f5f9;">🎯 Key Takeaways from Our AI Road Trip</h2>
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 20px 0; box-shadow: 0 4px 6px rgba(0,0,0,0.5); background: rgba(255, 255, 255, 0.05);">
#   <thead>
#     <tr style="background: rgba(255, 255, 255, 0.1); color: #f1f5f9; border: 2px solid rgba(255, 255, 255, 0.2);">
#       <th style="padding: 15px; text-align: center; border: 1px solid rgba(255, 255, 255, 0.2);">Stop</th>
#       <th style="padding: 15px; text-align: center; border: 1px solid rgba(255, 255, 255, 0.2);">City</th>
#       <th style="padding: 15px; text-align: center; border: 1px solid rgba(255, 255, 255, 0.2);">AI Concept</th>
#       <th style="padding: 15px; text-align: center; border: 1px solid rgba(255, 255, 255, 0.2);">Road Trip Parallel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background-color: rgba(255, 107, 107, 0.1);">
#       <td style="padding: 15px; text-align: center; border: 1px solid #ff6b6b; color: #e2e8f0;">1 🌴</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ff6b6b; color: #fca5a5;"><strong>San Diego</strong></td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ff6b6b; color: #e2e8f0;">Prompt Engineering</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ff6b6b; color: #e2e8f0;">Planning your itinerary</td>
#     </tr>
#     <tr style="background-color: rgba(78, 205, 196, 0.1);">
#       <td style="padding: 15px; text-align: center; border: 1px solid #4ecdc4; color: #e2e8f0;">2 🎬</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #4ecdc4; color: #5eead4;"><strong>Los Angeles</strong></td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #4ecdc4; color: #e2e8f0;">Context Awareness</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #4ecdc4; color: #e2e8f0;">Adapting to changes</td>
#     </tr>
#     <tr style="background-color: rgba(255, 217, 61, 0.1);">
#       <td style="padding: 15px; text-align: center; border: 1px solid #ffd93d; color: #e2e8f0;">3 🌉</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ffd93d; color: #fde047;"><strong>San Francisco</strong></td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ffd93d; color: #e2e8f0;">Pattern Recognition</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #ffd93d; color: #e2e8f0;">Learning best routes</td>
#     </tr>
#     <tr style="background-color: rgba(162, 155, 254, 0.1);">
#       <td style="padding: 15px; text-align: center; border: 1px solid #a29bfe; color: #e2e8f0;">4 🌲</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #a29bfe; color: #c4b5fd;"><strong>Seattle</strong></td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #a29bfe; color: #e2e8f0;">Continuous Improvement</td>
#       <td style="padding: 15px; text-align: center; border: 1px solid #a29bfe; color: #e2e8f0;">Reflecting & iterating</td>
#     </tr>
#   </tbody>
# </table>
#
# <hr style="border: none; border-top: 2px solid rgba(255, 255, 255, 0.2); margin: 30px 0;">
#
# <div style="background: rgba(255, 255, 255, 0.1); color: #f1f5f9; padding: 30px; border-radius: 15px; text-align: center; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.5); border: 3px solid rgba(255, 255, 255, 0.2);">
#   <h3 style="margin: 0 0 10px 0; font-size: 28px; color: #f1f5f9;">🚀 Next Steps</h3>
#   <p style="margin: 0; font-size: 18px; color: #cbd5e1;">Now that we understand the journey, we're ready to build our own AI applications!</p>
# </div>
#
# </div>
